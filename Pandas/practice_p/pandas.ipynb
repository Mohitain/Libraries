# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,6,6,7])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    6
# 5    7
# dtype: int64

# %%
s.name = "numbers"

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s.name = "calories"
