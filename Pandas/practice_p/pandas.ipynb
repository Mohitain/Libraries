# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,6,6,7])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    6
# 5    7
# dtype: int64

# %%
s.name = "numbers"

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    6
# 5    7
# Name: calories, dtype: int64

# %%
s.iloc[[2,3,]]
# Out:
# 2    3
# 3    6
# Name: calories, dtype: int64

# %%
index = ["apple","banana","cherry","tt","aa","gg"]

# %%
s.index = index

# %%
s
# Out:
# apple     1
# banana    2
# cherry    3
# tt        6
# aa        6
# gg        7
# Name: calories, dtype: int64

# %%
s['apple']
# Out:
# np.int64(1)

# %%
s.loc["banana"]
# Out:
# np.int64(2)

# %%
myfruits = {
    "Avocado":2.0,
    "Guava":2.1,
    "mango":1,
    "cherry":2
}

# %%
s2 =pd.Series(myfruits,name=("number"))

# %%
s2
# Out:
# Avocado    2.0
# Guava      2.1
# mango      1.0
# cherry     2.0
# Name: number, dtype: float64

# %%
s2[s2>1]
# Out:
# Avocado    2.0
# Guava      2.1
# cherry     2.0
# Name: number, dtype: float64

# %%
s2 = s2.rename(index={"cherry":"banana"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s2 = s2.rename(index={"cherry":"banana"})
#
# TypeError: 'set' object is not callable

# %%
s2
# Out:
# Avocado    2.0
# Guava      2.1
# mango      1.0
# cherry     2.0
# Name: number, dtype: float64
